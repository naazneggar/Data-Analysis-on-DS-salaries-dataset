# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("ds_salaries.csv")

# %%
data1
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
data1.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ### no null values anywhere in the data set

# %%
data1["job_title"].value_counts()
# Out:
# job_title
# Data Engineer                          1040
# Data Scientist                          840
# Data Analyst                            612
# Machine Learning Engineer               289
# Analytics Engineer                      103
#                                        ...
# Principal Machine Learning Engineer       1
# Azure Data Engineer                       1
# Manager Data Management                   1
# Marketing Data Engineer                   1
# Finance Data Analyst                      1
# Name: count, Length: 93, dtype: int64

# %% [markdown]
# ### We can see there are 93 unique job titles

# %% [markdown]
# ### Jobs with the top 20 highest salary

# %%
topsa=data1.groupby("job_title")["salary"].max()

# %%
topsasort=topsa.sort_values(ascending=False)
topsasort
# Out:
# job_title
# Data Scientist                    30400000
# BI Data Analyst                   11000000
# ML Engineer                        8500000
# Lead Machine Learning Engineer     7500000
# Data Science Manager               7000000
#                                     ...
# Finance Data Analyst                 45000
# Insight Analyst                      42000
# Compliance Data Analyst              30000
# Staff Data Analyst                   15000
# Product Data Scientist                8000
# Name: salary, Length: 93, dtype: int64

# %% [markdown]
# # Lets look top ten jobs related to Data engineering that may end up giving you maximum salary

# %%
plt.figure(figsize=(7,4))

data1.groupby("job_title")["salary_in_usd"].max().sort_values(ascending=False).head(10).plot(kind='bar')	
plt.xticks(rotation=90);
plt.title("Jobs that provide maximum salary in USD")
plt.xlabel("Job Title")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ### The data shows that Research Scientist may gain the highest salary compared to others in the same field.
# ### Data Analyst and AI Scientists being second and third respectivily, can also fetch high salary

# %% [markdown]
# # Lets look which jobs on Data engineering field has more average salaries

# %%
plt.figure(figsize=(10,8))

data1.groupby("job_title")["salary_in_usd"].mean().sort_values(ascending=False).head(10).plot(kind='bar')	
plt.xticks(rotation=90);
plt.title("Jobs that provide higher  salary")
# Out:
# Text(0.5, 1.0, 'Jobs that provide higher  salary')

# %% [markdown]
# ### Data Science Tech lead jobs earn the most salaries on average

# %%
import numpy as np
sns.barplot(x= '',y='day', data=tips, estimator='mean',hue='time')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %% [markdown]
# ## Checking if "experience level" has duplicates or not

# %%
has_duplicates = data1['experience_level'].duplicated().any()
print(f"Column 'experience_level' has duplicates: {has_duplicates}")
# Out:
# Column 'experience_level' has duplicates: True

# %%
data1["experience_level"].value_counts()
# Out:
# experience_level
# SE    2516
# MI     805
# EN     320
# EX     114
# Name: count, dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %% [markdown]
# # Comparing salaries with experience levels

# %%
pivot_table = data1.pivot_table(values='salary_in_usd', index='experience_level', aggfunc='mean', fill_value=0)
h=pivot_table.reset_index()
h
# Out:
#   experience_level  salary_in_usd
# 0               EN   78546.284375
# 1               EX  194930.929825
# 2               MI  104525.939130
# 3               SE  153051.071542

# %%
pivot_table.sort_values(by="salary_in_usd").plot(kind="bar")
# Out:
# <Axes: xlabel='experience_level'>

# %% [markdown]
# ### The mean salaries are going high with higher experience

# %%
pivot_table = top10.pivot_table(values='salary_in_usd', 
                             index='job_title', 
                             columns='experience_level', 
                             aggfunc='mean', 
                             fill_value=0)

print(pivot_table)
# Out:
# experience_level                          EX        MI        SE
# job_title
# AI Scientist                             0.0       0.0  423834.0
# Applied Data Scientist                   0.0       0.0  380000.0
# Applied Machine Learning Scientist       0.0  423000.0       0.0
# Data Analyst                             0.0  430967.0  385000.0
# Data Analytics Lead                      0.0       0.0  405000.0
# Data Architect                           0.0       0.0  376080.0
# Data Science Tech Lead                   0.0       0.0  375000.0
# Data Scientist                           0.0       0.0  412000.0
# Machine Learning Software Engineer       0.0       0.0  375000.0
# Principal Data Scientist            416000.0       0.0       0.0
# Research Scientist                       0.0  450000.0  370000.0

# %% [markdown]
# # Comparing top 13 high salaried job title with experience levels

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))

# Sort and get the top 13 job titles by salary
sorted_data = data1.sort_values(by="salary_in_usd", ascending=False)
top10 = sorted_data.head(13)



# Plot
sns.barplot(
    x='salary_in_usd',
    y='job_title',
    data=top10,
    estimator='mean',
    hue='experience_level',
    
)

plt.xlabel('Average Salary (USD)')
plt.ylabel('Job Title')
plt.title('Top 13 Job Titles by Salary with Experience Levels')
plt.legend(title='Experience Level')
plt.show()

# %% [markdown]
# ## It seems that mid level employees are paid more than senior level exployees in Research scientist and  Data analyst jobs. This seems counter intuitive
# ## May be its Performance-Based Pay: If mid-level employees are highly productive or contribute to critical projects, their performance-based bonuses MAY BE HIGH
#
# ## Or the data may be skewed,A few high salaries for mid-level roles could skew the average

# %% [markdown]
# # Lets compare maximum salary vs location

# %%
plt.figure(figsize=(7,4))

data1.groupby("company_location")["salary_in_usd"].max().sort_values(ascending=False).head(5).plot(kind='pie',shadow=True,autopct="%1.2f%%")	

plt.title("MAximum Salary vs Location")
# Out:
# Text(0.5, 1.0, 'MAximum Salary vs Location')

# %% [markdown]
# ### Locations DE and IN has low maximum salaries and US has more salary

# %% [markdown]
# ### Lets compare average salary vs location

# %%
plt.figure(figsize=(7,4))

data1.groupby("company_location")["salary_in_usd"].mean().sort_values(ascending=False).head(5).plot(kind='pie',shadow=True,autopct="%1.2f%%")	

plt.title("Average Salary vs Location")
# Out:
# Text(0.5, 1.0, 'Average Salary vs Location')

# %% [markdown]
# ### Location IL has more average salary and US has less average salary related to Data science

# %% [markdown]
# # Lets compare average salary vs company size

# %%
plt.figure(figsize=(7,4))

data1.groupby("company_size")["salary_in_usd"].mean().sort_values(ascending=False).plot(kind='pie',explode=[0.1,0,0],shadow=True,autopct="%1.2f%%")	

plt.title("Average Salary vs company size")
# Out:
# Text(0.5, 1.0, 'Average Salary vs company size')

# %% [markdown]
# ### The average salary in medium sized companies are more compared to small and large

# %%
y=data1["salary"]

plt.boxplot(y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x="day",data=tips) #plotting the value counts

# %%
data2=pd.read_csv("ds_salaries.csv")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrame creation


# Group by 'job_title' and 'experience_level', then calculate the mean salary
grouped_data = data2.groupby(['job_title', 'experience_level'])['salary_in_usd'].mean().reset_index()

# Sort values by 'salary_in_usd' in descending order
sorted_data = grouped_data.sort_values(by='salary_in_usd', ascending=False)
top10_jobs = sorted_data.head(10)

# Plot
plt.figure(figsize=(12, 8))
sns.barplot(
    x='salary_in_usd',
    y='job_title',
    hue='experience_level',
    data=top10_jobs,
    
)

plt.xlabel('Average Salary (USD)')
plt.ylabel('Job Title')
plt.title('Average Salary by Job Title and Experience Level')
plt.legend(title='Experience Level')
plt.show()
